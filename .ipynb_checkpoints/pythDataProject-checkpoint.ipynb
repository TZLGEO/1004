# %%
import pandas as pd

# %%
from flask import Flask

# %%
from sqlalchemy import create_engine, inspect, MetaData, Table
import subprocess

# %%
DATABASE_URL = subprocess.check_output("heroku config:get DATABASE_URL --app billboardchart2", shell=True).decode('utf-8')
engine = create_engine(DATABASE_URL)

# %%
metadata = MetaData()
metadata.create_all(engine)

# %%
with engine.connect() as con:
    query = """SELECT "Song", "Performer"  FROM billboard_chart WHERE "WeekID"= '1997-10-11'"""
    query2 = """SELECT * FROM billboard_chart LIMIT 20"""
    rs = con.execute(query2)

for row in r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-cd3f25e1ebd8> in <module>
#       4     rs = con.execute(query2)
#       5
# ----> 6 rs[1]
#
# TypeError: 'ResultProxy' object is not subscriptable

# %%
query_str1 = """SELECT "Song", count(*) AS cnt  
                        FROM billboard_chart 
                        GROUP BY "Song" 
                        ORDER BY cnt DESC"""

query_str2 = """SELECT "Song", count(*) AS cnt  
                        FROM billboard_chart 
                        WHERE ("Week Position" = 1)
                        GROUP BY "Song" 
                        ORDER BY cnt DESC"""

# %%
def test():
    x_values = []
    y_values = []
    values_list = []
    with engine.connect() as con:
        # change this to whatever query you want you want
        query_str = """SELECT "Song", count(*) AS cnt  
                        FROM billboard_chart 
                        GROUP BY "Song" 
                        ORDER BY cnt DESC
                        LIMIT 20"""

        rs = con.execute(query_str)

        for row in rs:
            values_list.append({"x_vals":row[1], "y_vals": row[1]})
            

            
    return values_list
            
dict = test()

# %%
dict
# Out:
# [{'x_vals': 207, 'y_vals': 207},
#  {'x_vals': 205, 'y_vals': 205},
#  {'x_vals': 194, 'y_vals': 194},
#  {'x_vals': 189, 'y_vals': 189},
#  {'x_vals': 188, 'y_vals': 188},
#  {'x_vals': 184, 'y_vals': 184},
#  {'x_vals': 177, 'y_vals': 177},
#  {'x_vals': 161, 'y_vals': 161},
#  {'x_vals': 157, 'y_vals': 157},
#  {'x_vals': 152, 'y_vals': 152},
#  {'x_vals': 152, 'y_vals': 152},
#  {'x_vals': 149, 'y_vals': 149},
#  {'x_vals': 140, 'y_vals': 140},
#  {'x_vals': 139, 'y_vals': 139},
#  {'x_vals': 138, 'y_vals': 138},
#  {'x_vals': 134, 'y_vals': 134},
#  {'x_vals': 132, 'y_vals': 132},
#  {'x_vals': 130, 'y_vals': 130},
#  {'x_vals': 128, 'y_vals': 128},
#  {'x_vals': 128, 'y_vals': 128}]

# %%
from flask import jsonify
jsonify(dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-101-8a7a0b0146ac> in <module>
#       1 from flask import jsonify
# ----> 2 jsonify(dict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# C:\ProgramData\Anaconda3\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     304         """
#     305         if not hasattr(self.__local, "__release_local__"):
# --> 306             return self.__local()
#     307         try:
#     308             return getattr(self.__local, self.__name__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\flask\globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.

# %%
query2 = """SELECT * FROM billboard_chart LIMIT 20"""
rs = engine.connect().execute(query2)
for row in rs:
    print (row)
# Out:
# ('http://www.billboard.com/charts/hot-100/1958-08-02', datetime.date(1958, 8, 2), 1, 'Poor Little Fool', 'Ricky Nelson', 'Poor Little FoolRicky Nelson', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/1995-12-02', datetime.date(1995, 12, 2), 1, 'One Sweet Day', 'Mariah Carey & Boyz II Men', 'One Sweet DayMariah Carey & Boyz II Men', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/1997-10-11', datetime.date(1997, 10, 11), 1, 'Candle In The Wind 1997/Something About The Way You Look Tonight', 'Elton John', 'Candle In The Wind 1997/Something About The Way You Look TonightElton John', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2006-07-01', datetime.date(2006, 7, 1), 1, 'Do I Make You Proud', 'Taylor Hicks', 'Do I Make You ProudTaylor Hicks', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2009-10-24', datetime.date(2009, 10, 24), 1, '3', 'Britney Spears', '3Britney Spears', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2011-02-26', datetime.date(2011, 2, 26), 1, 'Born This Way', 'Lady Gaga', 'Born This WayLady Gaga', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2012-03-03', datetime.date(2012, 3, 3), 1, 'Part Of Me', 'Katy Perry', 'Part Of MeKaty Perry', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2014-09-06', datetime.date(2014, 9, 6), 1, 'Shake It Off', 'Taylor Swift', 'Shake It OffTaylor Swift', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2016-02-20', datetime.date(2016, 2, 20), 1, 'Pillowtalk', 'Zayn', 'PillowtalkZayn', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2016-05-28', datetime.date(2016, 5, 28), 1, "Can't Stop The Feeling!", 'Justin Timberlake', "Can't Stop The Feeling!Justin Timberlake", 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/2017-01-28', datetime.date(2017, 1, 28), 1, 'Shape Of You', 'Ed Sheeran', 'Shape Of YouEd Sheeran', 1, None, 1, 1)
# ('https://www.billboard.com/charts/hot-100/2018-11-17', datetime.date(2018, 11, 17), 1, 'Thank U, Next', 'Ariana Grande', 'Thank U, NextAriana Grande', 1, None, 1, 1)
# ('https://www.billboard.com/charts/hot-100/2019-02-02', datetime.date(2019, 2, 2), 1, '7 Rings', 'Ariana Grande', '7 RingsAriana Grande', 1, None, 1, 1)
# ('https://www.billboard.com/charts/hot-100/2019-03-16', datetime.date(2019, 3, 16), 1, 'Sucker', 'Jonas Brothers', 'SuckerJonas Brothers', 1, None, 1, 1)
# ('http://www.billboard.com/charts/hot-100/1958-08-02', datetime.date(1958, 8, 2), 2, 'Patricia', 'Perez Prado And His Orchestra', 'PatriciaPerez Prado And His Orchestra', 1, None, 2, 1)
# ('http://www.billboard.com/charts/hot-100/1996-04-06', datetime.date(1996, 4, 6), 2, 'Always Be My Baby', 'Mariah Carey', 'Always Be My BabyMariah Carey', 1, None, 2, 1)
# ('http://www.billboard.com/charts/hot-100/1996-05-11', datetime.date(1996, 5, 11), 2, 'Tha Crossroads', 'Bone Thugs-N-Harmony', 'Tha CrossroadsBone Thugs-N-Harmony', 1, None, 2, 1)
# ('http://www.billboard.com/charts/hot-100/1997-09-27', datetime.date(1997, 9, 27), 2, '4 Seasons Of Loneliness', 'Boyz II Men', '4 Seasons Of LonelinessBoyz II Men', 1, None, 2, 1)
# ('http://www.billboard.com/charts/hot-100/2008-08-30', datetime.date(2008, 8, 30), 2, 'Crush', 'David Archuleta', 'CrushDavid Archuleta', 1, None, 2, 1)
# ('http://www.billboard.com/charts/hot-100/2009-08-29', datetime.date(2009, 8, 29), 2, 'Party In The U.S.A.', 'Miley Cyrus', 'Party In The U.S.A.Miley Cyrus', 1, None, 2, 1)

# %%
billboard_chart_table  = Table('billboard_chart', metadata, autoload=True, autoload_with=engine)
columns = [c.name for c in billboard_chart_table.columns]
print(columns)
# Out:
# ['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID', 'Instance', 'Previous Week Position', 'Peak Position', 'Weeks on Chart']

# %%
billboard_df = pd.read_sql_table("billboard_chart", con=engine)
billboard_df.shape
# Out:
# (320495, 10)

# %%
billboard_df.head(100)
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1958-0... 1958-08-02
# 1  http://www.billboard.com/charts/hot-100/1995-1... 1995-12-02
# 2  http://www.billboard.com/charts/hot-100/1997-1... 1997-10-11
# 3  http://www.billboard.com/charts/hot-100/2006-0... 2006-07-01
# 4  http://www.billboard.com/charts/hot-100/2009-1... 2009-10-24
#
#    Week Position                                               Song  \
# 0              1                                   Poor Little Fool
# 1              1                                      One Sweet Day
# 2              1  Candle In The Wind 1997/Something About The Wa...
# 3              1                                Do I Make You Proud
# 4              1                                                  3
#
#                     Performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
#
#                                               SongID  Instance  \
# 0                       Poor Little FoolRicky Nelson         1
# 1            One Sweet DayMariah Carey & Boyz II Men         1
# 2  Candle In The Wind 1997/Something About The Wa...         1
# 3                    Do I Make You ProudTaylor Hicks         1
# 4                                    3Britney Spears         1
#
#    Previous Week Position  Peak Position  Weeks on Chart
# 0                     NaN              1               1
# 1                     NaN              1               1
# 2                     NaN              1               1
# 3                     NaN              1               1
# 4                     NaN              1               1

# %%
billboard_df[billboard_df['Instance'] >1]
# Out:
#                                                       url     WeekID  \
# 304     http://www.billboard.com/charts/hot-100/1959-0... 1959-09-12
# 1157    https://www.billboard.com/charts/hot-100/2018-... 2018-03-24
# 1158    http://www.billboard.com/charts/hot-100/2012-0... 2012-02-18
# 1159    http://www.billboard.com/charts/hot-100/2003-1... 2003-11-08
# 1160    http://www.billboard.com/charts/hot-100/2016-0... 2016-05-14
# ...                                                   ...        ...
# 320490  https://www.billboard.com/charts/hot-100/2019-... 2019-01-05
# 320491  https://www.billboard.com/charts/hot-100/2019-... 2019-12-07
# 320492  https://www.billboard.com/charts/hot-100/2019-... 2019-12-14
# 320493  https://www.billboard.com/charts/hot-100/2019-... 2019-12-21
# 320494  https://www.billboard.com/charts/hot-100/2019-... 2019-12-28
#
#         Week Position                         Song      Performer  \
# 304                86  Don't Tell Me Your Troubles     Don Gibson
# 1157               90             Beautiful Trauma           P!nk
# 1158               90                Storm Warning   Hunter Hayes
# 1159               90    Pon De River, Pon De Bank   Elephant Man
# 1160               91                      Company  Justin Bieber
# ...               ...                          ...            ...
# 320490              8             Jingle Bell Rock    Bobby Helms
# 320491             47             Jingle Bell Rock    Bobby Helms
# 320492             23             Jingle Bell Rock    Bobby Helms
# 320493             15             Jingle Bell Rock    Bobby Helms
# 320494              9             Jingle Bell Rock    Bobby Helms
#
#                                        SongID  Instance  \
# 304     Don't Tell Me Your TroublesDon Gibson         2
# 1157                     Beautiful TraumaP!nk         2
# 1158                Storm WarningHunter Hayes         2
# 1159    Pon De River, Pon De BankElephant Man         2
# 1160                     CompanyJustin Bieber         2
# ...                                       ...       ...
# 320490            Jingle Bell RockBobby Helms         7
# 320491            Jingle Bell RockBobby Helms         8
# 320492            Jingle Bell RockBobby Helms         8
# 320493            Jingle Bell RockBobby Helms         8
# 320494            Jingle Bell RockBobby Helms         8
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 304                        NaN             86               3
# 1157                      81.0             78              12
# 1158                      84.0             78              12
# 1159                      90.0             86              12
# 1160                      58.0             53              12
# ...                        ...            ...             ...
# 320490                    13.0              8              25
# 320491                     NaN             47              26
# 320492                    47.0             23              27
# 320493                    23.0             15              28
# 320494                    15.0              9              29
#
# [17633 rows x 10 columns]

# %%
def get_data(df, rows):

    billboard_sample = df.iloc[:rows]
    result = billboard_sample.to_json(orient='records')
    return result

res = get_data(billboard_df, 5)

# %%
res
# Out:
# '[{"url":"http:\\/\\/www.billboard.com\\/charts\\/hot-100\\/1958-08-02","WeekID":-360288000000,"Week Position":1,"Song":"Poor Little Fool","Performer":"Ricky Nelson","SongID":"Poor Little FoolRicky Nelson","Instance":1,"Previous Week Position":null,"Peak Position":1,"Weeks on Chart":1},{"url":"http:\\/\\/www.billboard.com\\/charts\\/hot-100\\/1995-12-02","WeekID":817862400000,"Week Position":1,"Song":"One Sweet Day","Performer":"Mariah Carey & Boyz II Men","SongID":"One Sweet DayMariah Carey & Boyz II Men","Instance":1,"Previous Week Position":null,"Peak Position":1,"Weeks on Chart":1},{"url":"http:\\/\\/www.billboard.com\\/charts\\/hot-100\\/1997-10-11","WeekID":876528000000,"Week Position":1,"Song":"Candle In The Wind 1997\\/Something About The Way You Look Tonight","Performer":"Elton John","SongID":"Candle In The Wind 1997\\/Something About The Way You Look TonightElton John","Instance":1,"Previous Week Position":null,"Peak Position":1,"Weeks on Chart":1},{"url":"http:\\/\\/www.billboard.com\\/charts\\/hot-100\\/2006-07-01","WeekID":1151712000000,"Week Position":1,"Song":"Do I Make You Proud","Performer":"Taylor Hicks","SongID":"Do I Make You ProudTaylor Hicks","Instance":1,"Previous Week Position":null,"Peak Position":1,"Weeks on Chart":1},{"url":"http:\\/\\/www.billboard.com\\/charts\\/hot-100\\/2009-10-24","WeekID":1256342400000,"Week Position":1,"Song":"3","Performer":"Britney Spears","SongID":"3Britney Spears","Instance":1,"Previous Week Position":null,"Peak Position":1,"Weeks on Chart":1}]'

# %%
import pandasql as ps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-49881fb5fc94> in <module>
# ----> 1 import pandasql as ps
#
# ModuleNotFoundError: No module named 'pandasql'

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.18.5)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.0.5)
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.3.18)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pandasql) (1.15.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py): started
#   Building wheel for pandasql (setup.py): finished with status 'done'
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26822 sha256=434fe937cdd7a55e69bf21b7278488d71b35a6c85aeab217cbde2707e8efede5
#   Stored in directory: c:\users\glory\appdata\local\pip\cache\wheels\ed\8f\46\a383923333728744f01ba24adbd8e364f2cb9470a8b8e5b9ff
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
query = 'SELECT "Song", "Performer"  FROM billboard_chart WHERE "WeekID"= "1997-10-11"'

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

pysqldf(query)
# Out:
#                                                  url  \
# 0  http://www.billboard.com/charts/hot-100/1958-0...
# 1  http://www.billboard.com/charts/hot-100/1995-1...
# 2  http://www.billboard.com/charts/hot-100/1997-1...
# 3  http://www.billboard.com/charts/hot-100/2006-0...
# 4  http://www.billboard.com/charts/hot-100/2009-1...
# 5  http://www.billboard.com/charts/hot-100/2011-0...
# 6  http://www.billboard.com/charts/hot-100/2012-0...
# 7  http://www.billboard.com/charts/hot-100/2014-0...
# 8  http://www.billboard.com/charts/hot-100/2016-0...
# 9  http://www.billboard.com/charts/hot-100/2016-0...
#
#                        WeekID  Week Position  \
# 0  1958-08-02 00:00:00.000000              1
# 1  1995-12-02 00:00:00.000000              1
# 2  1997-10-11 00:00:00.000000              1
# 3  2006-07-01 00:00:00.000000              1
# 4  2009-10-24 00:00:00.000000              1
# 5  2011-02-26 00:00:00.000000              1
# 6  2012-03-03 00:00:00.000000              1
# 7  2014-09-06 00:00:00.000000              1
# 8  2016-02-20 00:00:00.000000              1
# 9  2016-05-28 00:00:00.000000              1
#
#                                                 Song  \
# 0                                   Poor Little Fool
# 1                                      One Sweet Day
# 2  Candle In The Wind 1997/Something About The Wa...
# 3                                Do I Make You Proud
# 4                                                  3
# 5                                      Born This Way
# 6                                         Part Of Me
# 7                                       Shake It Off
# 8                                         Pillowtalk
# 9                            Can't Stop The Feeling!
#
#                     Performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
# 5                   Lady Gaga
# 6                  Katy Perry
# 7                Taylor Swift
# 8                        Zayn
# 9           Justin Timberlake
#
#                                               SongID  Instance  \
# 0                       Poor Little FoolRicky Nelson         1
# 1            One Sweet DayMariah Carey & Boyz II Men         1
# 2  Candle In The Wind 1997/Something About The Wa...         1
# 3                    Do I Make You ProudTaylor Hicks         1
# 4                                    3Britney Spears         1
# 5                             Born This WayLady Gaga         1
# 6                               Part Of MeKaty Perry         1
# 7                           Shake It OffTaylor Swift         1
# 8                                     PillowtalkZayn         1
# 9           Can't Stop The Feeling!Justin Timberlake         1
#
#   Previous Week Position  Peak Position  Weeks on Chart
# 0                   None              1               1
# 1                   None              1               1
# 2                   None              1               1
# 3                   None              1               1
# 4                   None              1               1
# 5                   None              1               1
# 6                   None              1               1
# 7                   None              1               1
# 8                   None              1               1
# 9                   None              1               1

# %%
billboard_df['WeekID'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df_chart = pd.read_csv('https://query.data.world/s/wndh7zyhwek7q4n2ae4hu5hyi2gaql')
df_chart.head()
# Out:
#                                                  url      WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958
# 1  http://www.billboard.com/charts/hot-100/1995-1...   12/2/1995
# 2  http://www.billboard.com/charts/hot-100/1997-1...  10/11/1997
# 3  http://www.billboard.com/charts/hot-100/2006-0...    7/1/2006
# 4  http://www.billboard.com/charts/hot-100/2009-1...  10/24/2009
#
#    Week Position                                               Song  \
# 0              1                                   Poor Little Fool
# 1              1                                      One Sweet Day
# 2              1  Candle In The Wind 1997/Something About The Wa...
# 3              1                                Do I Make You Proud
# 4              1                                                  3
#
#                     Performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
#
#                                               SongID  Instance  \
# 0                       Poor Little FoolRicky Nelson         1
# 1            One Sweet DayMariah Carey & Boyz II Men         1
# 2  Candle In The Wind 1997/Something About The Wa...         1
# 3                    Do I Make You ProudTaylor Hicks         1
# 4                                    3Britney Spears         1
#
#    Previous Week Position  Peak Position  Weeks on Chart
# 0                     NaN              1               1
# 1                     NaN              1               1
# 2                     NaN              1               1
# 3                     NaN              1               1
# 4                     NaN              1               1

# %%
import json

# %%
billboard_sample = billboard_df.iloc[:100]
result = billboard_sample.to_json(orient='records')
parsed = json.loads(result)

parsed
# Out:
# [{'url': 'http://www.billboard.com/charts/hot-100/1958-08-02',
#   'WeekID': -360288000000,
#   'Week Position': 1,
#   'Song': 'Poor Little Fool',
#   'Performer': 'Ricky Nelson',
#   'SongID': 'Poor Little FoolRicky Nelson',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1995-12-02',
#   'WeekID': 817862400000,
#   'Week Position': 1,
#   'Song': 'One Sweet Day',
#   'Performer': 'Mariah Carey & Boyz II Men',
#   'SongID': 'One Sweet DayMariah Carey & Boyz II Men',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-10-11',
#   'WeekID': 876528000000,
#   'Week Position': 1,
#   'Song': 'Candle In The Wind 1997/Something About The Way You Look Tonight',
#   'Performer': 'Elton John',
#   'SongID': 'Candle In The Wind 1997/Something About The Way You Look TonightElton John',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2006-07-01',
#   'WeekID': 1151712000000,
#   'Week Position': 1,
#   'Song': 'Do I Make You Proud',
#   'Performer': 'Taylor Hicks',
#   'SongID': 'Do I Make You ProudTaylor Hicks',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2009-10-24',
#   'WeekID': 1256342400000,
#   'Week Position': 1,
#   'Song': '3',
#   'Performer': 'Britney Spears',
#   'SongID': '3Britney Spears',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2011-02-26',
#   'WeekID': 1298678400000,
#   'Week Position': 1,
#   'Song': 'Born This Way',
#   'Performer': 'Lady Gaga',
#   'SongID': 'Born This WayLady Gaga',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-03-03',
#   'WeekID': 1330732800000,
#   'Week Position': 1,
#   'Song': 'Part Of Me',
#   'Performer': 'Katy Perry',
#   'SongID': 'Part Of MeKaty Perry',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2014-09-06',
#   'WeekID': 1409961600000,
#   'Week Position': 1,
#   'Song': 'Shake It Off',
#   'Performer': 'Taylor Swift',
#   'SongID': 'Shake It OffTaylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-02-20',
#   'WeekID': 1455926400000,
#   'Week Position': 1,
#   'Song': 'Pillowtalk',
#   'Performer': 'Zayn',
#   'SongID': 'PillowtalkZayn',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-05-28',
#   'WeekID': 1464393600000,
#   'Week Position': 1,
#   'Song': "Can't Stop The Feeling!",
#   'Performer': 'Justin Timberlake',
#   'SongID': "Can't Stop The Feeling!Justin Timberlake",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-01-28',
#   'WeekID': 1485561600000,
#   'Week Position': 1,
#   'Song': 'Shape Of You',
#   'Performer': 'Ed Sheeran',
#   'SongID': 'Shape Of YouEd Sheeran',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-11-17',
#   'WeekID': 1542412800000,
#   'Week Position': 1,
#   'Song': 'Thank U, Next',
#   'Performer': 'Ariana Grande',
#   'SongID': 'Thank U, NextAriana Grande',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-02-02',
#   'WeekID': 1549065600000,
#   'Week Position': 1,
#   'Song': '7 Rings',
#   'Performer': 'Ariana Grande',
#   'SongID': '7 RingsAriana Grande',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-03-16',
#   'WeekID': 1552694400000,
#   'Week Position': 1,
#   'Song': 'Sucker',
#   'Performer': 'Jonas Brothers',
#   'SongID': 'SuckerJonas Brothers',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 1,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1958-08-02',
#   'WeekID': -360288000000,
#   'Week Position': 2,
#   'Song': 'Patricia',
#   'Performer': 'Perez Prado And His Orchestra',
#   'SongID': 'PatriciaPerez Prado And His Orchestra',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1996-04-06',
#   'WeekID': 828748800000,
#   'Week Position': 2,
#   'Song': 'Always Be My Baby',
#   'Performer': 'Mariah Carey',
#   'SongID': 'Always Be My BabyMariah Carey',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1996-05-11',
#   'WeekID': 831772800000,
#   'Week Position': 2,
#   'Song': 'Tha Crossroads',
#   'Performer': 'Bone Thugs-N-Harmony',
#   'SongID': 'Tha CrossroadsBone Thugs-N-Harmony',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-09-27',
#   'WeekID': 875318400000,
#   'Week Position': 2,
#   'Song': '4 Seasons Of Loneliness',
#   'Performer': 'Boyz II Men',
#   'SongID': '4 Seasons Of LonelinessBoyz II Men',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2008-08-30',
#   'WeekID': 1220054400000,
#   'Week Position': 2,
#   'Song': 'Crush',
#   'Performer': 'David Archuleta',
#   'SongID': 'CrushDavid Archuleta',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2009-08-29',
#   'WeekID': 1251504000000,
#   'Week Position': 2,
#   'Song': 'Party In The U.S.A.',
#   'Performer': 'Miley Cyrus',
#   'SongID': 'Party In The U.S.A.Miley Cyrus',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-05-29',
#   'WeekID': 1275091200000,
#   'Week Position': 2,
#   'Song': 'California Gurls',
#   'Performer': 'Katy Perry Featuring Snoop Dogg',
#   'SongID': 'California GurlsKaty Perry Featuring Snoop Dogg',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-04-14',
#   'WeekID': 1334361600000,
#   'Week Position': 2,
#   'Song': 'Boyfriend',
#   'Performer': 'Justin Bieber',
#   'SongID': 'BoyfriendJustin Bieber',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2013-08-10',
#   'WeekID': 1376092800000,
#   'Week Position': 2,
#   'Song': 'Best Song Ever',
#   'Performer': 'One Direction',
#   'SongID': 'Best Song EverOne Direction',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2015-11-14',
#   'WeekID': 1447459200000,
#   'Week Position': 2,
#   'Song': 'Sorry',
#   'Performer': 'Justin Bieber',
#   'SongID': 'SorryJustin Bieber',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-08-13',
#   'WeekID': 1471046400000,
#   'Week Position': 2,
#   'Song': 'Cold Water',
#   'Performer': 'Major Lazer Featuring Justin Bieber & MO',
#   'SongID': 'Cold WaterMajor Lazer Featuring Justin Bieber & MO',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-10-07',
#   'WeekID': 1507334400000,
#   'Week Position': 2,
#   'Song': 'Rockstar',
#   'Performer': 'Post Malone Featuring 21 Savage',
#   'SongID': 'RockstarPost Malone Featuring 21 Savage',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-03-10',
#   'WeekID': 1520640000000,
#   'Week Position': 2,
#   'Song': 'Psycho',
#   'Performer': 'Post Malone Featuring Ty Dolla $ign',
#   'SongID': 'PsychoPost Malone Featuring Ty Dolla $ign',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-02-23',
#   'WeekID': 1550880000000,
#   'Week Position': 2,
#   'Song': "Break Up With Your Girlfriend, I'm Bored",
#   'Performer': 'Ariana Grande',
#   'SongID': "Break Up With Your Girlfriend, I'm BoredAriana Grande",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-07-06',
#   'WeekID': 1562371200000,
#   'Week Position': 2,
#   'Song': 'Senorita',
#   'Performer': 'Shawn Mendes & Camila Cabello',
#   'SongID': 'SenoritaShawn Mendes & Camila Cabello',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 2,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1958-08-02',
#   'WeekID': -360288000000,
#   'Week Position': 3,
#   'Song': 'Splish Splash',
#   'Performer': 'Bobby Darin',
#   'SongID': 'Splish SplashBobby Darin',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1998-10-03',
#   'WeekID': 907372800000,
#   'Week Position': 3,
#   'Song': 'One Week',
#   'Performer': 'Barenaked Ladies',
#   'SongID': 'One WeekBarenaked Ladies',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2008-12-20',
#   'WeekID': 1229731200000,
#   'Week Position': 3,
#   'Song': 'Circus',
#   'Performer': 'Britney Spears',
#   'SongID': 'CircusBritney Spears',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2011-09-03',
#   'WeekID': 1315008000000,
#   'Week Position': 3,
#   'Song': 'She Will',
#   'Performer': 'Lil Wayne Featuring Drake',
#   'SongID': 'She WillLil Wayne Featuring Drake',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-05-05',
#   'WeekID': 1336176000000,
#   'Week Position': 3,
#   'Song': 'Payphone',
#   'Performer': 'Maroon 5 Featuring Wiz Khalifa',
#   'SongID': 'PayphoneMaroon 5 Featuring Wiz Khalifa',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2013-09-14',
#   'WeekID': 1379116800000,
#   'Week Position': 3,
#   'Song': 'Berzerk',
#   'Performer': 'Eminem',
#   'SongID': 'BerzerkEminem',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2014-05-17',
#   'WeekID': 1400284800000,
#   'Week Position': 3,
#   'Song': 'Problem',
#   'Performer': 'Ariana Grande Featuring Iggy Azalea',
#   'SongID': 'ProblemAriana Grande Featuring Iggy Azalea',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 3,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2004-04-03',
#   'WeekID': 1080950400000,
#   'Week Position': 4,
#   'Song': 'Solitaire',
#   'Performer': 'Clay Aiken',
#   'SongID': 'SolitaireClay Aiken',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2009-06-06',
#   'WeekID': 1244246400000,
#   'Week Position': 4,
#   'Song': "Don't Stop Believin'",
#   'Performer': 'Glee Cast',
#   'SongID': "Don't Stop Believin'Glee Cast",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-03-04',
#   'WeekID': 1488585600000,
#   'Week Position': 4,
#   'Song': 'Chained To The Rhythm',
#   'Performer': 'Katy Perry Featuring Skip Marley',
#   'SongID': 'Chained To The RhythmKaty Perry Featuring Skip Marley',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-04-29',
#   'WeekID': 1493424000000,
#   'Week Position': 4,
#   'Song': 'Sign Of The Times',
#   'Performer': 'Harry Styles',
#   'SongID': 'Sign Of The TimesHarry Styles',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-05-06',
#   'WeekID': 1494028800000,
#   'Week Position': 4,
#   'Song': 'DNA.',
#   'Performer': 'Kendrick Lamar',
#   'SongID': 'DNA.Kendrick Lamar',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-09-23',
#   'WeekID': 1506124800000,
#   'Week Position': 4,
#   'Song': '...Ready For It?',
#   'Performer': 'Taylor Swift',
#   'SongID': '...Ready For It?Taylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-04-14',
#   'WeekID': 1523664000000,
#   'Week Position': 4,
#   'Song': 'Call Out My Name',
#   'Performer': 'The Weeknd',
#   'SongID': 'Call Out My NameThe Weeknd',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-08-18',
#   'WeekID': 1534550400000,
#   'Week Position': 4,
#   'Song': 'Sicko Mode',
#   'Performer': 'Travis Scott',
#   'SongID': 'Sicko ModeTravis Scott',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-10-19',
#   'WeekID': 1571443200000,
#   'Week Position': 4,
#   'Song': '10,000 Hours',
#   'Performer': 'Dan + Shay & Justin Bieber',
#   'SongID': '10,000 HoursDan + Shay & Justin Bieber',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 4,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1995-06-17',
#   'WeekID': 803347200000,
#   'Week Position': 5,
#   'Song': 'Scream/Childhood',
#   'Performer': 'Michael Jackson & Janet Jackson',
#   'SongID': 'Scream/ChildhoodMichael Jackson & Janet Jackson',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1995-06-24',
#   'WeekID': 803952000000,
#   'Week Position': 5,
#   'Song': 'One More Chance/Stay With Me',
#   'Performer': 'The Notorious B.I.G.',
#   'SongID': 'One More Chance/Stay With MeThe Notorious B.I.G.',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-05-24',
#   'WeekID': 864432000000,
#   'Week Position': 5,
#   'Song': "Say You'll Be There",
#   'Performer': 'Spice Girls',
#   'SongID': "Say You'll Be ThereSpice Girls",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1998-07-11',
#   'WeekID': 900115200000,
#   'Week Position': 5,
#   'Song': 'Ray Of Light',
#   'Performer': 'Madonna',
#   'SongID': 'Ray Of LightMadonna',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2008-07-12',
#   'WeekID': 1215820800000,
#   'Week Position': 5,
#   'Song': "Burnin' Up",
#   'Performer': 'Jonas Brothers',
#   'SongID': "Burnin' UpJonas Brothers",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2008-09-27',
#   'WeekID': 1222473600000,
#   'Week Position': 5,
#   'Song': 'Swagga Like Us',
#   'Performer': 'Jay-Z & T.I. Featuring Kanye West & Lil Wayne',
#   'SongID': 'Swagga Like UsJay-Z & T.I. Featuring Kanye West & Lil Wayne',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-02-06',
#   'WeekID': 1265414400000,
#   'Week Position': 5,
#   'Song': 'Baby',
#   'Performer': 'Justin Bieber Featuring Ludacris',
#   'SongID': 'BabyJustin Bieber Featuring Ludacris',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-10-29',
#   'WeekID': 1477699200000,
#   'Week Position': 5,
#   'Song': '24K Magic',
#   'Performer': 'Bruno Mars',
#   'SongID': '24K MagicBruno Mars',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-10-13',
#   'WeekID': 1539388800000,
#   'Week Position': 5,
#   'Song': "Don't Cry",
#   'Performer': 'Lil Wayne Featuring XXXTENTACION',
#   'SongID': "Don't CryLil Wayne Featuring XXXTENTACION",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-03-02',
#   'WeekID': 1551484800000,
#   'Week Position': 5,
#   'Song': 'Please Me',
#   'Performer': 'Cardi B & Bruno Mars',
#   'SongID': 'Please MeCardi B & Bruno Mars',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 5,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1958-08-02',
#   'WeekID': -360288000000,
#   'Week Position': 6,
#   'Song': "Rebel-'rouser",
#   'Performer': 'Duane Eddy His Twangy Guitar And The Rebels',
#   'SongID': "Rebel-'rouserDuane Eddy His Twangy Guitar And The Rebels",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1995-09-16',
#   'WeekID': 811209600000,
#   'Week Position': 6,
#   'Song': 'Runaway',
#   'Performer': 'Janet Jackson',
#   'SongID': 'RunawayJanet Jackson',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-08-16',
#   'WeekID': 871689600000,
#   'Week Position': 6,
#   'Song': '2 Become 1',
#   'Performer': 'Spice Girls',
#   'SongID': '2 Become 1Spice Girls',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-09-04',
#   'WeekID': 1283558400000,
#   'Week Position': 6,
#   'Song': 'Right Above It',
#   'Performer': 'Lil Wayne Featuring Drake',
#   'SongID': 'Right Above ItLil Wayne Featuring Drake',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-10-30',
#   'WeekID': 1288396800000,
#   'Week Position': 6,
#   'Song': 'Back To December',
#   'Performer': 'Taylor Swift',
#   'SongID': 'Back To DecemberTaylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-10-20',
#   'WeekID': 1350691200000,
#   'Week Position': 6,
#   'Song': 'Red',
#   'Performer': 'Taylor Swift',
#   'SongID': 'RedTaylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2013-08-31',
#   'WeekID': 1377907200000,
#   'Week Position': 6,
#   'Song': 'Applause',
#   'Performer': 'Lady Gaga',
#   'SongID': 'ApplauseLady Gaga',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2013-11-16',
#   'WeekID': 1384560000000,
#   'Week Position': 6,
#   'Song': 'Story Of My Life',
#   'Performer': 'One Direction',
#   'SongID': 'Story Of My LifeOne Direction',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2014-08-16',
#   'WeekID': 1408147200000,
#   'Week Position': 6,
#   'Song': 'Bang Bang',
#   'Performer': 'Jessie J, Ariana Grande & Nicki Minaj',
#   'SongID': 'Bang BangJessie J, Ariana Grande & Nicki Minaj',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-02-20',
#   'WeekID': 1455926400000,
#   'Week Position': 6,
#   'Song': 'Summer Sixteen',
#   'Performer': 'Drake',
#   'SongID': 'Summer SixteenDrake',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-01-28',
#   'WeekID': 1485561600000,
#   'Week Position': 6,
#   'Song': 'Castle On The Hill',
#   'Performer': 'Ed Sheeran',
#   'SongID': 'Castle On The HillEd Sheeran',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-05-05',
#   'WeekID': 1525478400000,
#   'Week Position': 6,
#   'Song': 'ATM',
#   'Performer': 'J. Cole',
#   'SongID': 'ATMJ. Cole',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 6,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-03-29',
#   'WeekID': 859593600000,
#   'Week Position': 7,
#   'Song': 'All By Myself',
#   'Performer': 'Celine Dion',
#   'SongID': 'All By MyselfCeline Dion',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-09-06',
#   'WeekID': 873504000000,
#   'Week Position': 7,
#   'Song': 'Barbie Girl',
#   'Performer': 'Aqua',
#   'SongID': 'Barbie GirlAqua',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2007-08-04',
#   'WeekID': 1186185600000,
#   'Week Position': 7,
#   'Song': 'Sorry, Blame It On Me',
#   'Performer': 'Akon',
#   'SongID': 'Sorry, Blame It On MeAkon',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-01-23',
#   'WeekID': 1264204800000,
#   'Week Position': 7,
#   'Song': 'Blah Blah Blah',
#   'Performer': 'Ke$ha Featuring 3OH!3',
#   'SongID': 'Blah Blah BlahKe$ha Featuring 3OH!3',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2011-10-15',
#   'WeekID': 1318636800000,
#   'Week Position': 7,
#   'Song': 'Strange Clouds',
#   'Performer': 'B.o.B Featuring Lil Wayne',
#   'SongID': 'Strange CloudsB.o.B Featuring Lil Wayne',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-10-13',
#   'WeekID': 1350086400000,
#   'Week Position': 7,
#   'Song': 'Begin Again',
#   'Performer': 'Taylor Swift',
#   'SongID': 'Begin AgainTaylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2013-11-02',
#   'WeekID': 1383350400000,
#   'Week Position': 7,
#   'Song': 'Rap God',
#   'Performer': 'Eminem',
#   'SongID': 'Rap GodEminem',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-12-31',
#   'WeekID': 1483142400000,
#   'Week Position': 7,
#   'Song': 'Deja Vu',
#   'Performer': 'J. Cole',
#   'SongID': 'Deja VuJ. Cole',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-02-04',
#   'WeekID': 1486166400000,
#   'Week Position': 7,
#   'Song': 'Paris',
#   'Performer': 'The Chainsmokers',
#   'SongID': 'ParisThe Chainsmokers',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-02-03',
#   'WeekID': 1517616000000,
#   'Week Position': 7,
#   'Song': 'Diplomatic Immunity',
#   'Performer': 'Drake',
#   'SongID': 'Diplomatic ImmunityDrake',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-02-17',
#   'WeekID': 1518825600000,
#   'Week Position': 7,
#   'Song': 'Pray For Me',
#   'Performer': 'The Weeknd & Kendrick Lamar',
#   'SongID': 'Pray For MeThe Weeknd & Kendrick Lamar',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-05-12',
#   'WeekID': 1526083200000,
#   'Week Position': 7,
#   'Song': 'Better Now',
#   'Performer': 'Post Malone',
#   'SongID': 'Better NowPost Malone',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-04-13',
#   'WeekID': 1555113600000,
#   'Week Position': 7,
#   'Song': 'Bad Guy',
#   'Performer': 'Billie Eilish',
#   'SongID': 'Bad GuyBillie Eilish',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-09-14',
#   'WeekID': 1568419200000,
#   'Week Position': 7,
#   'Song': 'Circles',
#   'Performer': 'Post Malone',
#   'SongID': 'CirclesPost Malone',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 7,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2014-12-13',
#   'WeekID': 1418428800000,
#   'Week Position': 18,
#   'Song': '7/11',
#   'Performer': 'Beyonce',
#   'SongID': '7/11Beyonce',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 18,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1997-07-12',
#   'WeekID': 868665600000,
#   'Week Position': 8,
#   'Song': 'Sunny Came Home',
#   'Performer': 'Shawn Colvin',
#   'SongID': 'Sunny Came HomeShawn Colvin',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2005-05-07',
#   'WeekID': 1115424000000,
#   'Week Position': 8,
#   'Song': 'Speed Of Sound',
#   'Performer': 'Coldplay',
#   'SongID': 'Speed Of SoundColdplay',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-06-05',
#   'WeekID': 1275696000000,
#   'Week Position': 8,
#   'Song': "Can't Be Tamed",
#   'Performer': 'Miley Cyrus',
#   'SongID': "Can't Be TamedMiley Cyrus",
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-10-23',
#   'WeekID': 1287792000000,
#   'Week Position': 8,
#   'Song': 'Speak Now',
#   'Performer': 'Taylor Swift',
#   'SongID': 'Speak NowTaylor Swift',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2010-11-27',
#   'WeekID': 1290816000000,
#   'Week Position': 8,
#   'Song': 'Teenage Dream',
#   'Performer': 'Glee Cast',
#   'SongID': 'Teenage DreamGlee Cast',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2012-10-20',
#   'WeekID': 1350691200000,
#   'Week Position': 8,
#   'Song': 'Skyfall',
#   'Performer': 'Adele',
#   'SongID': 'SkyfallAdele',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2015-01-31',
#   'WeekID': 1422662400000,
#   'Week Position': 8,
#   'Song': 'Sugar',
#   'Performer': 'Maroon 5',
#   'SongID': 'SugarMaroon 5',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2016-03-19',
#   'WeekID': 1458345600000,
#   'Week Position': 8,
#   'Song': 'Piece By Piece',
#   'Performer': 'Kelly Clarkson',
#   'SongID': 'Piece By PieceKelly Clarkson',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2017-04-08',
#   'WeekID': 1491609600000,
#   'Week Position': 8,
#   'Song': 'Passionfruit',
#   'Performer': 'Drake',
#   'SongID': 'PassionfruitDrake',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2018-08-18',
#   'WeekID': 1534550400000,
#   'Week Position': 8,
#   'Song': 'Stargazing',
#   'Performer': 'Travis Scott',
#   'SongID': 'StargazingTravis Scott',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-04-27',
#   'WeekID': 1556323200000,
#   'Week Position': 8,
#   'Song': 'Boy With Luv',
#   'Performer': 'BTS Featuring Halsey',
#   'SongID': 'Boy With LuvBTS Featuring Halsey',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-08-17',
#   'WeekID': 1566000000000,
#   'Week Position': 8,
#   'Song': 'Boyfriend',
#   'Performer': 'Ariana Grande & Social House',
#   'SongID': 'BoyfriendAriana Grande & Social House',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'https://www.billboard.com/charts/hot-100/2019-09-21',
#   'WeekID': 1569024000000,
#   'Week Position': 8,
#   'Song': 'Take What You Want',
#   'Performer': 'Post Malone Featuring Ozzy Osbourne & Travis Scott',
#   'SongID': 'Take What You WantPost Malone Featuring Ozzy Osbourne & Travis Scott',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 8,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/1996-07-20',
#   'WeekID': 837820800000,
#   'Week Position': 9,
#   'Song': 'Change The World',
#   'Performer': 'Eric Clapton',
#   'SongID': 'Change The WorldEric Clapton',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 9,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2008-09-06',
#   'WeekID': 1220659200000,
#   'Week Position': 9,
#   'Song': 'So What',
#   'Performer': 'P!nk',
#   'SongID': 'So WhatP!nk',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 9,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2009-11-14',
#   'WeekID': 1258156800000,
#   'Week Position': 9,
#   'Song': 'Bad Romance',
#   'Performer': 'Lady Gaga',
#   'SongID': 'Bad RomanceLady Gaga',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 9,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2011-01-01',
#   'WeekID': 1293840000000,
#   'Week Position': 9,
#   'Song': '6 Foot 7 Foot',
#   'Performer': 'Lil Wayne Featuring Cory Gunz',
#   'SongID': '6 Foot 7 FootLil Wayne Featuring Cory Gunz',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 9,
#   'Weeks on Chart': 1},
#  {'url': 'http://www.billboard.com/charts/hot-100/2011-12-03',
#   'WeekID': 1322870400000,
#   'Week Position': 9,
#   'Song': 'Take Care',
#   'Performer': 'Drake Featuring Rihanna',
#   'SongID': 'Take CareDrake Featuring Rihanna',
#   'Instance': 1,
#   'Previous Week Position': None,
#   'Peak Position': 9,
#   'Weeks on Chart': 1}]

# %%
billboard_json = json.dumps(parsed, indent=4)
billboard_json
# Out:
# '[\n    {\n        "url": "http://www.billboard.com/charts/hot-100/1958-08-02",\n        "WeekID": -360288000000,\n        "Week Position": 1,\n        "Song": "Poor Little Fool",\n        "Performer": "Ricky Nelson",\n        "SongID": "Poor Little FoolRicky Nelson",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/1995-12-02",\n        "WeekID": 817862400000,\n        "Week Position": 1,\n        "Song": "One Sweet Day",\n        "Performer": "Mariah Carey & Boyz II Men",\n        "SongID": "One Sweet DayMariah Carey & Boyz II Men",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/1997-10-11",\n        "WeekID": 876528000000,\n        "Week Position": 1,\n        "Song": "Candle In The Wind 1997/Something About The Way You Look Tonight",\n        "Performer": "Elton John",\n        "SongID": "Candle In The Wind 1997/Something About The Way You Look TonightElton John",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2006-07-01",\n        "WeekID": 1151712000000,\n        "Week Position": 1,\n        "Song": "Do I Make You Proud",\n        "Performer": "Taylor Hicks",\n        "SongID": "Do I Make You ProudTaylor Hicks",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2009-10-24",\n        "WeekID": 1256342400000,\n        "Week Position": 1,\n        "Song": "3",\n        "Performer": "Britney Spears",\n        "SongID": "3Britney Spears",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2011-02-26",\n        "WeekID": 1298678400000,\n        "Week Position": 1,\n        "Song": "Born This Way",\n        "Performer": "Lady Gaga",\n        "SongID": "Born This WayLady Gaga",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2012-03-03",\n        "WeekID": 1330732800000,\n        "Week Position": 1,\n        "Song": "Part Of Me",\n        "Performer": "Katy Perry",\n        "SongID": "Part Of MeKaty Perry",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2014-09-06",\n        "WeekID": 1409961600000,\n        "Week Position": 1,\n        "Song": "Shake It Off",\n        "Performer": "Taylor Swift",\n        "SongID": "Shake It OffTaylor Swift",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2016-02-20",\n        "WeekID": 1455926400000,\n        "Week Position": 1,\n        "Song": "Pillowtalk",\n        "Performer": "Zayn",\n        "SongID": "PillowtalkZayn",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        "Weeks on Chart": 1\n    },\n    {\n        "url": "http://www.billboard.com/charts/hot-100/2016-05-28",\n        "WeekID": 1464393600000,\n        "Week Position": 1,\n        "Song": "Can\'t Stop The Feeling!",\n        "Performer": "Justin Timberlake",\n        "SongID": "Can\'t Stop The Feeling!Justin Timberlake",\n        "Instance": 1,\n        "Previous Week Position": null,\n        "Peak Position": 1,\n        " ...

# %%
df_chart.to_sql('billboard_chart', engine, if_exists='replace',chunksize=10000, index=False)

# %%
inspector = inspect(engine)
inspector.get_columns('billboard_chart')
# Out:
# [{'name': 'url',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'WeekID',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Week Position',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Song',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Performer',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'SongID',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Instance',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Previous Week Position',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Peak Position',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Weeks on Chart',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %%
from sqlalchemy.sql import text

# %%
from sqlalchemy.ext.automap import automap_base

Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# mapped classes are now created with names by default
# matching that of the table name.
chart = Base.classes

# %%
chart.billboard_chart
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\pythData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'billboard_chart'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-8125ffe0d66a> in <module>
# ----> 1 chart.billboard_chart
#
# ~\.conda\envs\pythData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: billboard_chart

# %%
engine.table_names()
# Out:
# ['billboard_chart']
